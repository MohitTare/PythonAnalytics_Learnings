# %%
import pandas as pd
import numpy as np
import matplotlib as mp
from pandas import Series,DataFrame
# %matplotlib inline

# %%
df = pd.read_csv('E:\Analytics Practice\Data sets\dataset_diabetes\diabetic_data.csv')

# %%
df.head(10)
# Out:
#    encounter_id  patient_nbr             race  gender       age weight  \
# 0       2278392      8222157        Caucasian  Female    [0-10)      ?
# 1        149190     55629189        Caucasian  Female   [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female   [20-30)      ?
# 3        500364     82442376        Caucasian    Male   [30-40)      ?
# 4         16680     42519267        Caucasian    Male   [40-50)      ?
# 5         35754     82637451        Caucasian    Male   [50-60)      ?
# 6         55842     84259809        Caucasian    Male   [60-70)      ?
# 7         63768    114882984        Caucasian    Male   [70-80)      ?
# 8         12522     48330783        Caucasian  Female   [80-90)      ?
# 9         15738     63555939        Caucasian  Female  [90-100)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# ...

# %%
df.replace('?',np.nan)
# Out:
#         encounter_id  patient_nbr             race  gender       age weight  \
# 0            2278392      8222157        Caucasian  Female    [0-10)    NaN
# 1             149190     55629189        Caucasian  Female   [10-20)    NaN
# 2              64410     86047875  AfricanAmerican  Female   [20-30)    NaN
# 3             500364     82442376        Caucasian    Male   [30-40)    NaN
# 4              16680     42519267        Caucasian    Male   [40-50)    NaN
# 5              35754     82637451        Caucasian    Male   [50-60)    NaN
# 6              55842     84259809        Caucasian    Male   [60-70)    NaN
# 7              63768    114882984        Caucasian    Male   [70-80)    NaN
# 8              12522     48330783        Caucasian  Female   [80-90)    NaN
# 9              15738     63555939        Caucasian  Female  [90-100)    NaN
# 10             28236     89869032  AfricanAmerican  Female   [40-50)    NaN
# ...

# %%
df['age']
# Out:
# 0           [0-10)
# 1          [10-20)
# 2          [20-30)
# 3          [30-40)
# 4          [40-50)
# 5          [50-60)
# 6          [60-70)
# 7          [70-80)
# 8          [80-90)
# 9         [90-100)
# 10         [40-50)
# 11         [60-70)
# 12         [40-50)
# 13         [80-90)
# 14         [60-70)
# 15         [60-70)
# 16         [50-60)
# 17         [50-60)
# 18         [70-80)
# 19         [70-80)
# 20         [50-60)
# 21         [60-70)
# 22         [70-80)
# 23         [80-90)
# 24         [70-80)
# 25         [50-60)
# 26         [80-90)
# 27         [50-60)
# 28         [20-30)
# 29         [80-90)
#             ...
# 101736     [60-70)
# 101737     [40-50)
# 101738     [70-80)
# 101739     [70-80)
# 101740     [40-50)
# 101741    [90-100)
# 101742     [70-80)
# 101743     [80-90)
# 101744     [80-90)
# 101745     [50-60)
# 101746     [70-80)
# 101747     [70-80)
# 101748     [40-50)
# 101749     [70-80)
# 101750     [80-90)
# 101751     [70-80)
# ...

# %%
type(df['age'])
# Out:
# pandas.core.series.Series

# %%
df['age'].replace(')',']')
# Out:
# 0           [0-10)
# 1          [10-20)
# 2          [20-30)
# 3          [30-40)
# 4          [40-50)
# 5          [50-60)
# 6          [60-70)
# 7          [70-80)
# 8          [80-90)
# 9         [90-100)
# 10         [40-50)
# 11         [60-70)
# 12         [40-50)
# 13         [80-90)
# 14         [60-70)
# 15         [60-70)
# 16         [50-60)
# 17         [50-60)
# 18         [70-80)
# 19         [70-80)
# 20         [50-60)
# 21         [60-70)
# 22         [70-80)
# 23         [80-90)
# 24         [70-80)
# 25         [50-60)
# 26         [80-90)
# 27         [50-60)
# 28         [20-30)
# 29         [80-90)
#             ...
# 101736     [60-70)
# 101737     [40-50)
# 101738     [70-80)
# 101739     [70-80)
# 101740     [40-50)
# 101741    [90-100)
# 101742     [70-80)
# 101743     [80-90)
# 101744     [80-90)
# 101745     [50-60)
# 101746     [70-80)
# 101747     [70-80)
# 101748     [40-50)
# 101749     [70-80)
# 101750     [80-90)
# 101751     [70-80)
# ...

# %%
df['age']
# Out:
# 0           [0-10)
# 1          [10-20)
# 2          [20-30)
# 3          [30-40)
# 4          [40-50)
# 5          [50-60)
# 6          [60-70)
# 7          [70-80)
# 8          [80-90)
# 9         [90-100)
# 10         [40-50)
# 11         [60-70)
# 12         [40-50)
# 13         [80-90)
# 14         [60-70)
# 15         [60-70)
# 16         [50-60)
# 17         [50-60)
# 18         [70-80)
# 19         [70-80)
# 20         [50-60)
# 21         [60-70)
# 22         [70-80)
# 23         [80-90)
# 24         [70-80)
# 25         [50-60)
# 26         [80-90)
# 27         [50-60)
# 28         [20-30)
# 29         [80-90)
#             ...
# 101736     [60-70)
# 101737     [40-50)
# 101738     [70-80)
# 101739     [70-80)
# 101740     [40-50)
# 101741    [90-100)
# 101742     [70-80)
# 101743     [80-90)
# 101744     [80-90)
# 101745     [50-60)
# 101746     [70-80)
# 101747     [70-80)
# 101748     [40-50)
# 101749     [70-80)
# 101750     [80-90)
# 101751     [70-80)
# ...

# %%
df.replace(')',']')
# Out:
#         encounter_id  patient_nbr             race  gender       age weight  \
# 0            2278392      8222157        Caucasian  Female    [0-10)      ?
# 1             149190     55629189        Caucasian  Female   [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female   [20-30)      ?
# 3             500364     82442376        Caucasian    Male   [30-40)      ?
# 4              16680     42519267        Caucasian    Male   [40-50)      ?
# 5              35754     82637451        Caucasian    Male   [50-60)      ?
# 6              55842     84259809        Caucasian    Male   [60-70)      ?
# 7              63768    114882984        Caucasian    Male   [70-80)      ?
# 8              12522     48330783        Caucasian  Female   [80-90)      ?
# 9              15738     63555939        Caucasian  Female  [90-100)      ?
# 10             28236     89869032  AfricanAmerican  Female   [40-50)      ?
# ...

# %%
def Calcnewage(x):
    if(x == '[0-10)'):
        return np.mean(range(0,10))
    elif(x == '[10-20)'):
        return np.mean(range(10,20))
    elif(x == '[30-40)'):
        return np.mean(range(30,40))
    elif(x == '[40-50)'):
        return np.mean(range(40,50))
    elif(x == '[50-60)'):
        return np.mean(range(50,60))
    elif(x == '[60-70)'):
        return np.mean(range(60,70))
    elif(x == '[70-80)'):
        return np.mean(range(70,80))
    elif(x == '[80-90)'):
        return np.mean(range(80,90))
    else:
        return np.mean(range(90,100))
    
    
df['age_new'] = df['age'].apply(Calcnewage)

# %%
df['age_new']
# Out:
# 0          4.5
# 1         14.5
# 2         94.5
# 3         34.5
# 4         44.5
# 5         54.5
# 6         64.5
# 7         74.5
# 8         84.5
# 9         94.5
# 10        44.5
# 11        64.5
# 12        44.5
# 13        84.5
# 14        64.5
# 15        64.5
# 16        54.5
# 17        54.5
# 18        74.5
# 19        74.5
# 20        54.5
# 21        64.5
# 22        74.5
# 23        84.5
# 24        74.5
# 25        54.5
# 26        84.5
# 27        54.5
# 28        94.5
# 29        84.5
#           ...
# 101736    64.5
# 101737    44.5
# 101738    74.5
# 101739    74.5
# 101740    44.5
# 101741    94.5
# 101742    74.5
# 101743    84.5
# 101744    84.5
# 101745    54.5
# 101746    74.5
# 101747    74.5
# 101748    44.5
# 101749    74.5
# 101750    84.5
# 101751    74.5
# 101752    44.5
# 101753    44.5
# 101754    74.5
# 101755    44.5
# 101756    64.5
# 101757    74.5
# 101758    84.5
# 101759    84.5
# 101760    64.5
# 101761    74.5
# 101762    84.5
# ...

# %%
df.head(10)
# Out:
#    encounter_id  patient_nbr             race  gender       age weight  \
# 0       2278392      8222157        Caucasian  Female    [0-10)      ?
# 1        149190     55629189        Caucasian  Female   [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female   [20-30)      ?
# 3        500364     82442376        Caucasian    Male   [30-40)      ?
# 4         16680     42519267        Caucasian    Male   [40-50)      ?
# 5         35754     82637451        Caucasian    Male   [50-60)      ?
# 6         55842     84259809        Caucasian    Male   [60-70)      ?
# 7         63768    114882984        Caucasian    Male   [70-80)      ?
# 8         12522     48330783        Caucasian  Female   [80-90)      ?
# 9         15738     63555939        Caucasian  Female  [90-100)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# ...

# %%
df = df.replace('?',np.nan)

# %%
df.head(10)
# Out:
#    encounter_id  patient_nbr             race  gender       age weight  \
# 0       2278392      8222157        Caucasian  Female    [0-10)    NaN
# 1        149190     55629189        Caucasian  Female   [10-20)    NaN
# 2         64410     86047875  AfricanAmerican  Female   [20-30)    NaN
# 3        500364     82442376        Caucasian    Male   [30-40)    NaN
# 4         16680     42519267        Caucasian    Male   [40-50)    NaN
# 5         35754     82637451        Caucasian    Male   [50-60)    NaN
# 6         55842     84259809        Caucasian    Male   [60-70)    NaN
# 7         63768    114882984        Caucasian    Male   [70-80)    NaN
# 8         12522     48330783        Caucasian  Female   [80-90)    NaN
# 9         15738     63555939        Caucasian  Female  [90-100)    NaN
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# ...

# %%
 df['weight'].value_counts()
# Out:
# [75-100)     1336
# [50-75)       897
# [100-125)     625
# [125-150)     145
# [25-50)        97
# [0-25)         48
# [150-175)      35
# [175-200)      11
# >200            3
# dtype: int64

# %%
df['age_new'].hist()

# %%
 df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# encounter_id                    0
# patient_nbr                     0
# race                         2273
# gender                          0
# age                             0
# weight                      98569
# admission_type_id               0
# discharge_disposition_id        0
# admission_source_id             0
# time_in_hospital                0
# payer_code                  40256
# medical_specialty           49949
# num_lab_procedures              0
# num_procedures                  0
# num_medications                 0
# number_outpatient               0
# number_emergency                0
# number_inpatient                0
# diag_1                         21
# diag_2                        358
# diag_3                       1423
# number_diagnoses                0
# max_glu_serum                   0
# A1Cresult                       0
# metformin                       0
# repaglinide                     0
# nateglinide                     0
# ...

# %%
# Creating a new variable weight_new and counts
def calcnewweight(x):
    if(x == '[0-25)'):
        return np.mean(range(0,25))
    elif(x == '[25-50)'):
        return np.mean(range(25,50))
    elif(x == '[50-75)'):
        return np.mean(range(50,70))
    elif(x == '[75-100)'):
        return np.mean(range(75,100))
    elif(x == '[100-125)'):
        return np.mean(range(100,125))
    elif(x == '[125-150)'):
        return np.mean(range(125,150))
    elif(x == '[175-200)'):
        return np.mean(range(175,200))
    elif(pd.isnull(x)):
        return np.nan
    else:
        return 200

df['weight_new'] = df['weight'].apply(calcnewweight)

# %%
df['weight'].value_counts()
# Out:
# ?            98569
# [75-100)      1336
# [50-75)        897
# [100-125)      625
# [125-150)      145
# [25-50)         97
# [0-25)          48
# [150-175)       35
# [175-200)       11
# >200             3
# dtype: int64

# %%
df['weight_new'].value_counts()
# Out:
# 87.0     1336
# 59.5      897
# 112.0     625
# 137.0     145
# 37.0       97
# 12.0       48
# 200.0      38
# 187.0      11
# dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-a3a8c8539839> in <module>()
# ----> 1 df['weight_new'].fillna()
#
# C:\Users\mtare\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\core\series.pyc in fillna(self, value, method, axis, inplace, limit, downcast, **kwargs)
#    2157                                           axis=axis, inplace=inplace,
#    2158                                           limit=limit, downcast=downcast,
# -> 2159                                           **kwargs)
#    2160
#    2161     @Appender(generic._shared_docs['shift'] % _shared_doc_kwargs)
#
# C:\Users\mtare\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\core\generic.pyc in fillna(self, value, method, axis, inplace, limit, downcast)
#    2522         if value is None:
#    2523             if method is None:
# ...

# %%
df['weight_new'].hist()

# %%
df['weight_new'].fillna(df['weight_new'].mode())
# Out:
# 0         87
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
#           ..
# 101736   NaN
# 101737   NaN
# 101738   NaN
# 101739   NaN
# 101740   NaN
# 101741   NaN
# 101742   NaN
# 101743   NaN
# 101744   NaN
# 101745   NaN
# 101746   NaN
# 101747   NaN
# 101748   NaN
# 101749   NaN
# 101750   NaN
# 101751   NaN
# 101752   NaN
# 101753   NaN
# 101754   NaN
# 101755   NaN
# 101756   NaN
# 101757   NaN
# 101758   NaN
# 101759   NaN
# 101760   NaN
# 101761   NaN
# 101762   NaN
# 101763   NaN
# 101764   NaN
# 101765   NaN
# Name: weight_new, dtype: float64

# %%
df['weight_new'].hist()

# %%
df['weight_new'].value_counts()
# Out:
# 87.0     1336
# 59.5      897
# 112.0     625
# 137.0     145
# 37.0       97
# 12.0       48
# 200.0      38
# 187.0      11
# dtype: int64

# %%
df['weight_new']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
#           ..
# 101736   NaN
# 101737   NaN
# 101738   NaN
# 101739   NaN
# 101740   NaN
# 101741   NaN
# 101742   NaN
# 101743   NaN
# 101744   NaN
# 101745   NaN
# 101746   NaN
# 101747   NaN
# 101748   NaN
# 101749   NaN
# 101750   NaN
# 101751   NaN
# 101752   NaN
# 101753   NaN
# 101754   NaN
# 101755   NaN
# 101756   NaN
# 101757   NaN
# 101758   NaN
# 101759   NaN
# 101760   NaN
# 101761   NaN
# 101762   NaN
# 101763   NaN
# 101764   NaN
# 101765   NaN
# Name: weight_new, dtype: float64

# %%
df['weight_new'].fillna(df['weight_new'].mode(),inplace = True)

# %%
df['weight_new'].hist(bins = 50)

# %%
df['weight_new'].value_counts()
# Out:
# 87.0     1336
# 59.5      897
# 112.0     625
# 137.0     145
# 37.0       97
# 12.0       48
# 200.0      38
# 187.0      11
# dtype: int64

# %%
df['race'].unique()
# Out:
# array(['Caucasian', 'AfricanAmerican', nan, 'Other', 'Asian', 'Hispanic'], dtype=object)

# %%
df['race'].value_counts()
# Out:
# Caucasian          76099
# AfricanAmerican    19210
# Hispanic            2037
# Other               1506
# Asian                641
# dtype: int64

# %%
 df.count()
# Out:
# encounter_id                101766
# patient_nbr                 101766
# race                         99493
# gender                      101766
# age                         101766
# weight                        3197
# admission_type_id           101766
# discharge_disposition_id    101766
# admission_source_id         101766
# time_in_hospital            101766
# payer_code                   61510
# medical_specialty            51817
# num_lab_procedures          101766
# num_procedures              101766
# num_medications             101766
# number_outpatient           101766
# number_emergency            101766
# number_inpatient            101766
# diag_1                      101745
# diag_2                      101408
# diag_3                      100343
# number_diagnoses            101766
# max_glu_serum               101766
# A1Cresult                   101766
# metformin                   101766
# repaglinide                 101766
# nateglinide                 101766
# ...

# %%
temp3 = pd.crosstab(df['race'], df['diabetesMed'])
temp3
# Out:
# diabetesMed         No    Yes
# race
# AfricanAmerican   4412  14798
# Asian              166    475
# Caucasian        17649  58450
# Hispanic           486   1551
# Other              288   1218

# %%
df['race'].value_counts()
# Out:
# Caucasian          76099
# AfricanAmerican    19210
# Hispanic            2037
# Other               1506
# Asian                641
# dtype: int64

# %%
df = df.dropna(subset = ['race'])

# %%
df.count()
# Out:
# encounter_id                99493
# patient_nbr                 99493
# race                        99493
# gender                      99493
# age                         99493
# weight                       3059
# admission_type_id           99493
# discharge_disposition_id    99493
# admission_source_id         99493
# time_in_hospital            99493
# payer_code                  59781
# medical_specialty           50727
# num_lab_procedures          99493
# num_procedures              99493
# num_medications             99493
# number_outpatient           99493
# number_emergency            99493
# number_inpatient            99493
# diag_1                      99474
# diag_2                      99157
# diag_3                      98144
# number_diagnoses            99493
# max_glu_serum               99493
# A1Cresult                   99493
# metformin                   99493
# repaglinide                 99493
# nateglinide                 99493
# ...

# %%
df['gender'].value_counts()
# Out:
# Female             53575
# Male               45917
# Unknown/Invalid        1
# dtype: int64

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Male', 'Unknown/Invalid'], dtype=object)

# %%
df = df.replace('Unknown/Invalid',np.nan)

# %%
df['gender'].value_counts()
# Out:
# Female    53575
# Male      45917
# dtype: int64

# %%
 from sklearn.preprocessing import LabelEncoder
var_mod = ['gender','race']
le = LabelEncoder()
for i in var_mod:
    df[i] = le.fit_transform(df[i])
df.dtypes
# Out:
# encounter_id                  int64
# patient_nbr                   int64
# race                          int32
# gender                        int32
# age                          object
# weight                       object
# admission_type_id             int64
# discharge_disposition_id      int64
# admission_source_id           int64
# time_in_hospital              int64
# payer_code                   object
# medical_specialty            object
# num_lab_procedures            int64
# num_procedures                int64
# num_medications               int64
# number_outpatient             int64
# number_emergency              int64
# number_inpatient              int64
# diag_1                       object
# diag_2                       object
# diag_3                       object
# number_diagnoses              int64
# max_glu_serum                object
# A1Cresult                    object
# metformin                    object
# repaglinide                  object
# ...

# %%
#Import models from scikit learn module:
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import KFold   #For K-fold cross validation
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import metrics

#Generic function for making a classification model and accessing performance:
def classification_model(model, data, predictors, outcome):
  #Fit the model:
  model.fit(data[predictors],data[outcome])
  
  #Make predictions on training set:
  predictions = model.predict(data[predictors])
  
  #Print accuracy
  accuracy = metrics.accuracy_score(predictions,data[outcome])
  print "Accuracy : %s" % "{0:.3%}".format(accuracy)

  #Perform k-fold cross-validation with 5 folds
  kf = KFold(data.shape[0], n_folds=5)
  error = []
  for train, test in kf:
    # Filter training data
    train_predictors = (data[predictors].iloc[train,:])
    
    # The target we're using to train the algorithm.
    train_target = data[outcome].iloc[train]
    
    # Training the algorithm using the predictors and target.
    model.fit(train_predictors, train_target)
    
    #Record error from each cross-validation run
    error.append(model.score(data[predictors].iloc[test,:], data[outcome].iloc[test]))
 
  print "Cross-Validation Score : %s" % "{0:.3%}".format(np.mean(error))

  #Fit the model again so that it can be refered outside the function:
  model.fit(data[predictors],data[outcome])

# %% [markdown]
# # Predicting Diabetes Med based on Patient characteristics

# %%
outcome_var = 'diabetesMed'
model = LogisticRegression()
predictor_var = ['gender','race','age_new','num_medications','time_in_hospital']
classification_model(model,df,predictor_var,outcome_var)
# Out:
# Accuracy : 76.886%
# Cross-Validation Score : 76.885%

# %%
outcome_var = 'diabetesMed'
model = DecisionTreeClassifier()
predictor_var = ['gender','race','age_new','num_medications',]
classification_model(model,df,predictor_var,outcome_var)
# Out:
# Accuracy : 77.644%
# Cross-Validation Score : 76.792%

# %%
featimp = pd.Series(model.feature_importances_, index=predictor_var)
print featimp
# Out:
# gender             0.035658
# race               0.087985
# age_new            0.164178
# num_medications    0.712180
# dtype: float64
